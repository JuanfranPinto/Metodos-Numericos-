# %% [markdown]
# <h3 style="text-align:center;">ESCUELA POLITÉCNICA NACIONAL</h3>
# <h3 style="text-align:center;">FACULTAD DE INGENIERÍA EN SISTEMAS</h3>
# <h3 style="text-align:center;">METODOS NUMERICOS ICCD412 </h3>

# %% [markdown]
# *JUAN FRANCISCO PINTO ANDRANGO*
#
# *Taller 3b Métodos Iterativos*
#
# *GR1CC*
#
# *FECHA DE ENTREGA 20 DE ENERO DEL 2026*

# %% [markdown]
# ### Grafique la trayectoria de los siguientes sistemas de ecuaciones:
# ### Ejercicio 1
#
# $X_1 + X_2 = 7$
#
# $2X_1 +5X_2 = 0$
#
# $X_0 = (0,0)$
#
# $X_0 = (5,2) $

# %% [markdown]
# ### Ejercicio 2
#
# $X_1 +X_2 = 6$
#
# $-2X_1 + X_2 = 0$

# %% [markdown]
# ### Ejercicio 3
# ![image.png](attachment:image.png)
#
# Prueba 3 posiciones iniciales, encuentre una en la diverga el sistema
