# %% [markdown]
# <h3 style="text-align:center;">ESCUELA POLITÉCNICA NACIONAL</h3>
# <h3 style="text-align:center;">FACULTAD DE INGENIERÍA EN SISTEMAS</h3>
# <h3 style="text-align:center;">METODOS NUMERICOS ICCD412 </h3>

# %% [markdown]
# *JUAN FRANCISCO PINTO ANDRANGO*
#
# *Tarea 10-5 Matriz inversa descomposición LU *
#
# *GR1CC*
#
# *FECHA DE ENTREGA 8 de ENERO DEL 2026*

# %% [markdown]
# #### 1 calcule la matriz inversa con el método de Gauss-Jordan,

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2 calcule la descomposición LU.

# %% [markdown]
# ![image.png](attachment:image.png)
